# %% [markdown]
# # Check Emojis
#
# Given emotion, count and print the emojis in the data files.

# %%
import os
import re
import json
import pandas as pd
from pathlib import Path

# %%
relations_path = Path('../sentiment_analysis/query_relations.json')
with relations_path.open('r') as file:
    relations = json.load(file)

# %% [markdown]
# **emotion**: It will take all the queries from the relations data corresponding to the given emotion.

# %%
emotion = 'sadness'
queries = [key for key, value in relations.items() if value == emotion]

# %%
files_dir = Path('../datasets/tweepy').resolve()
data = []
for filename in os.listdir(files_dir):
    file_query = re.findall(r'(#[^.]+|:.+:)', filename)[0]
    if file_query in queries:
        data += [pd.read_csv(os.path.join(files_dir, filename))]

# %%
data = pd.concat(data)

# %%
from emoji import demojize, emojize

# %%
data['text'] = data.text.apply(lambda x: re.findall(r':[a-z_]+:', demojize(x)))

# %%
emoji_dict = {}
for i, emojis in data.text.iteritems():
    for emoji in emojis:
        if emoji in emoji_dict:
            emoji_dict[emoji] += 1
        else:
            emoji_dict[emoji] = 1

# %% [markdown]
# ## Results
#
# After the counting process, we'll plot the data to see which emojis are most used for the emotion.

# %%
for emoji, count in sorted(emoji_dict.items(), key=lambda x: x[1], reverse=True):
    print(emojize(emoji) + '(' + emoji + '): ' + str(count))
# Out:
# 😭(:loudly_crying_face:): 3691
# 😢(:crying_face:): 2410
# 😂(:face_with_tears_of_joy:): 452
# ❤(:red_heart:): 226
# 💔(:broken_heart:): 180
# 🤣(:rolling_on_the_floor_laughing:): 109
# 😩(:weary_face:): 91
# 💕(:two_hearts:): 91
# 😔(:pensive_face:): 77
# 🥺(:pleading_face:): 55
# 💗(:growing_heart:): 46
# 🙄(:face_with_rolling_eyes:): 42
# 💙(:blue_heart:): 42
# 🙏(:folded_hands:): 41
# 🔥(:fire:): 41
# 😫(:tired_face:): 38
# 💀(:skull:): 37
# 🧟‍♂️(:man_zombie:): 36
# 💜(:purple_heart:): 34
# 💖(:sparkling_heart:): 31
# 🤧(:sneezing_face:): 27
# 💞(:revolving_hearts:): 25
# 😞(:disappointed_face:): 24
# 🖤(:black_heart:): 24
# 😡(:pouting_face:): 23
# 😳(:flushed_face:): 23
# 🥴(:woozy_face:): 23
# 😪(:sleepy_face:): 23
# 😓(:downcast_face_with_sweat:): 22
# 😤(:face_with_steam_from_nose:): 21
# 😅(:grinning_face_with_sweat:): 20
# 😥(:sad_but_relieved_face:): 20
# 🗣(:speaking_head:): 20
# 🤔(:thinking_face:): 19
# 💓(:beating_heart:): 19
# ☹(:frowning_face:): 19
# ♥(:heart_suit:): 18
# 😆(:grinning_squinting_face:): 17
# 🙏🏻(:folded_hands_light_skin_tone:): 16
# 😒(:unamused_face:): 15
# 💛(:yellow_heart:): 15
# 😣(:persevering_face:): 15
# 👀(:eyes:): 15
# 🤡(:clown_face:): 15
# 👎(:thumbs_down:): 14
# 💯(:hundred_points:): 14
# 😑(:expressionless_face:): 14
# 🤬(:face_with_symbols_on_mouth:): 14
# 😱(:face_screaming_in_fear:): 13
# ✨(:sparkles:): 12
# 😊(:smiling_face_with_smiling_eyes:): 12
# 😖(:confounded_face:): 12
# 💚(:green_heart:): 12
# 💘(:heart_with_arrow:): 12
# 😬(:grimacing_face:): 11
# 🤪(:zany_face:): 11
# 🤯(:exploding_head:): 11
# 😰(:anxious_face_with_sweat:): 11
# 🤗(:hugging_face:): 11
# 🤦🏽‍♂️(:man_facepalming_medium_skin_tone:): 11
# 🏁(:chequered_flag:): 10
# 😘(:face_blowing_a_kiss:): 10
# 🤦🏽‍♀️(:woman_facepalming_medium_skin_tone:): 10
# 😕(:confused_face:): 10
# 🤭(:face_with_hand_over_mouth:): 10
# 👏🏽(:clapping_hands_medium_skin_tone:): 10
# 👍(:thumbs_up:): 9
# 🙁(:slightly_frowning_face:): 9
# 🐶(:dog_face:): 9
# 🤮(:face_vomiting:): 9
# 💩(:pile_of_poo:): 9
# 😐(:neutral_face:): 9
# 😠(:angry_face:): 8
# 🥵(:hot_face:): 8
# 🙌🏽(:raising_hands_medium_skin_tone:): 8
# 💰(:money_bag:): 8
# 😴(:sleeping_face:): 8
# 🎉(:party_popper:): 8
# 😉(:winking_face:): 8
# 👁(:eye:): 8
# 😁(:beaming_face_with_smiling_eyes:): 7
# 🙏🏽(:folded_hands_medium_skin_tone:): 7
# 🐾(:paw_prints:): 7
# 😟(:worried_face:): 7
# 😀(:grinning_face:): 7
# 🦇(:bat:): 7
# 🤦‍♀️(:woman_facepalming:): 7
# ‼(:double_exclamation_mark:): 7
# ✋(:raised_hand:): 7
# 💦(:sweat_droplets:): 7
# 😝(:squinting_face_with_tongue:): 7
# 👏(:clapping_hands:): 7
# 🥳(:partying_face:): 6
# 🧐(:face_with_monocle:): 6
# 🤢(:nauseated_face:): 6
# 🌟(:glowing_star:): 6
# 😎(:smiling_face_with_sunglasses:): 6
# ✌🏽(:victory_hand_medium_skin_tone:): 6
# 👽(:alien:): 6
# 😌(:relieved_face:): 6
# 🍕(:pizza:): 5
# 😃(:grinning_face_with_big_eyes:): 5
# 🕊(:dove:): 5
# 🤤(:drooling_face:): 5
# 🙂(:slightly_smiling_face:): 5
# 🤷‍♀️(:woman_shrugging:): 5
# 😮(:face_with_open_mouth:): 5
# 😇(:smiling_face_with_halo:): 5
# 😄(:grinning_face_with_smiling_eyes:): 5
# ▪(:black_small_square:): 5
# 🎨(:artist_palette:): 5
# 🌈(:rainbow:): 4
# 😈(:smiling_face_with_horns:): 4
# 🤓(:nerd_face:): 4
# 🔫(:pistol:): 4
# ❣(:heavy_heart_exclamation:): 4
# 😋(:face_savoring_food:): 4
# 💨(:dashing_away:): 4
# 👑(:crown:): 4
# 😗(:kissing_face:): 4
# 😧(:anguished_face:): 4
# ☺(:smiling_face:): 4
# 🤥(:lying_face:): 4
# 😶(:face_without_mouth:): 4
# 💋(:kiss_mark:): 4
# 😛(:face_with_tongue:): 4
# 🤞🏽(:crossed_fingers_medium_skin_tone:): 4
# 👊(:oncoming_fist:): 4
# 😨(:fearful_face:): 4
# ❗(:exclamation_mark:): 4
# 🤨(:face_with_raised_eyebrow:): 4
# 😏(:smirking_face:): 4
# 🤷🏿‍♂️(:man_shrugging_dark_skin_tone:): 4
# 🚶(:person_walking:): 4
# ⬇(:down_arrow:): 4
# 💲(:heavy_dollar_sign:): 4
# 😹(:cat_face_with_tears_of_joy:): 4
# 🤒(:face_with_thermometer:): 3
# 🍻(:clinking_beer_mugs:): 3
# ☀(:sun:): 3
# 🤲🏿(:palms_up_together_dark_skin_tone:): 3
# 😜(:winking_face_with_tongue:): 3
# ☠(:skull_and_crossbones:): 3
# ✌(:victory_hand:): 3
# 👸(:princess:): 3
# 🍆(:eggplant:): 3
# 🎻(:violin:): 3
# 😦(:frowning_face_with_open_mouth:): 3
# 💸(:money_with_wings:): 3
# 🤷‍♂️(:man_shrugging:): 3
# 🤦‍♂️(:man_facepalming:): 3
# 🧡(:orange_heart:): 3
# 🎷(:saxophone:): 3
# 🐞(:lady_beetle:): 3
# 💐(:bouquet:): 3
# 🚫(:prohibited:): 3
# 🙌(:raising_hands:): 3
# ⤵(:right_arrow_curving_down:): 3
# 😿(:crying_cat_face:): 3
# 🌹(:rose:): 2
# 🎂(:birthday_cake:): 2
# 🐏(:ram:): 2
# 😯(:hushed_face:): 2
# 📝(:memo:): 2
# 📣(:megaphone:): 2
# ✝(:latin_cross:): 2
# 🤘(:sign_of_the_horns:): 2
# 💟(:heart_decoration:): 2
# 📸(:camera_with_flash:): 2
# 🤷🏻‍♂️(:man_shrugging_light_skin_tone:): 2
# 💪🏽(:flexed_biceps_medium_skin_tone:): 2
# 👫(:man_and_woman_holding_hands:): 2
# 🌴(:palm_tree:): 2
# 👼(:baby_angel:): 2
# 🍑(:peach:): 2
# ™(:trade_mark:): 2
# 👣(:footprints:): 2
# 🍝(:spaghetti:): 2
# 🌻(:sunflower:): 2
# ✔(:heavy_check_mark:): 2
# 💪(:flexed_biceps:): 2
# 🦁(:lion_face:): 2
# 🐑(:ewe:): 2
# ⚡(:high_voltage:): 2
# 🤷🏻‍♀️(:woman_shrugging_light_skin_tone:): 2
# 🐈(:cat:): 2
# ®(:registered:): 2
# 🎶(:musical_notes:): 2
# ⚽(:soccer_ball:): 2
# 👩🏻‍💻(:woman_technologist_light_skin_tone:): 2
# ❌(:cross_mark:): 2
# 🤠(:cowboy_hat_face:): 2
# 💎(:gem_stone:): 2
# 🤷🏽‍♀️(:woman_shrugging_medium_skin_tone:): 2
# 🐢(:turtle:): 2
# ☔(:umbrella_with_rain_drops:): 2
# 🍦(:soft_ice_cream:): 2
# 🍊(:tangerine:): 2
# 🥀(:wilted_flower:): 2
# 💢(:anger_symbol:): 2
# 💬(:speech_balloon:): 2
# ♾(:infinity:): 2
# 🌞(:sun_with_face:): 2
# 🖐(:hand_with_fingers_splayed:): 2
# ✈(:airplane:): 2
# 🐯(:tiger_face:): 2
# ✊🏻(:raised_fist_light_skin_tone:): 2
# 🥁(:drum:): 2
# 👏🏻(:clapping_hands_light_skin_tone:): 2
# 🐎(:horse:): 2
# 🦄(:unicorn_face:): 2
# 💪🏿(:flexed_biceps_dark_skin_tone:): 1
# 📷(:camera:): 1
# 🍁(:maple_leaf:): 1
# ❄(:snowflake:): 1
# 🌺(:hibiscus:): 1
# 🍼(:baby_bottle:): 1
# 🤲🏽(:palms_up_together_medium_skin_tone:): 1
# 👨‍👩‍👧‍👧(:family_man_woman_girl_girl:): 1
# ⚛(:atom_symbol:): 1
# 👩‍🔬(:woman_scientist:): 1
# 💣(:bomb:): 1
# 🔊(:speaker_high_volume:): 1
# 👨‍🎤(:man_singer:): 1
# 💥(:collision:): 1
# 🏍(:motorcycle:): 1
# 👶(:baby:): 1
# 📢(:loudspeaker:): 1
# 🐖(:pig:): 1
# 🎼(:musical_score:): 1
# 🙏🏿(:folded_hands_dark_skin_tone:): 1
# 🤴🏽(:prince_medium_skin_tone:): 1
# 🏏(:cricket_game:): 1
# 🌧(:cloud_with_rain:): 1
# 💏(:kiss:): 1
# 🦋(:butterfly:): 1
# 🌮(:taco:): 1
# 🍤(:fried_shrimp:): 1
# 😚(:kissing_face_with_closed_eyes:): 1
# 💒(:wedding:): 1
# 👆🏻(:backhand_index_pointing_up_light_skin_tone:): 1
# 🎯(:direct_hit:): 1
# 🐕(:dog:): 1
# ⚾(:baseball:): 1
# 🍓(:strawberry:): 1
# 🙋🏻‍♀️(:woman_raising_hand_light_skin_tone:): 1
# 🤦(:person_facepalming:): 1
# 📱(:mobile_phone:): 1
# 🚛(:articulated_lorry:): 1
# 👩🏽‍🎓(:woman_student_medium_skin_tone:): 1
# 💃🏽(:woman_dancing_medium_skin_tone:): 1
# 👩🏽‍💻(:woman_technologist_medium_skin_tone:): 1
# 👯‍♀️(:women_with_bunny_ears:): 1
# 🥂(:clinking_glasses:): 1
# 🍽(:fork_and_knife_with_plate:): 1
# 🍫(:chocolate_bar:): 1
# 🍔(:hamburger:): 1
# 🙇🏽‍♀️(:woman_bowing_medium_skin_tone:): 1
# ✅(:white_heavy_check_mark:): 1
# 💁‍♂️(:man_tipping_hand:): 1
# ▶(:play_button:): 1
# 🚤(:speedboat:): 1
# 🌔(:waxing_gibbous_moon:): 1
# 👈(:backhand_index_pointing_left:): 1
# 🌷(:tulip:): 1
# 🏋️‍♂️(:man_lifting_weights:): 1
# 🤙(:call_me_hand:): 1
# 😲(:astonished_face:): 1
# 🐅(:tiger:): 1
# 🔒(:locked:): 1
# 🎸(:guitar:): 1
# 🤦🏻‍♀️(:woman_facepalming_light_skin_tone:): 1
# 👺(:goblin:): 1
# 👿(:angry_face_with_horns:): 1
# 🍪(:cookie:): 1
# 🏇(:horse_racing:): 1
# 🏃(:person_running:): 1
# 🤙🏽(:call_me_hand_medium_skin_tone:): 1
# 🛑(:stop_sign:): 1
# 🔪(:kitchen_knife:): 1
# ☎(:telephone:): 1
# 💫(:dizzy:): 1
# ♣(:club_suit:): 1
# ☁(:cloud:): 1
# 🦎(:lizard:): 1
# 👩🏻‍⚕️(:woman_health_worker_light_skin_tone:): 1
# 🎮(:video_game:): 1
# 🤷(:person_shrugging:): 1
# 👙(:bikini:): 1
# 🌬(:wind_face:): 1
# 🎁(:wrapped_gift:): 1
# 🦉(:owl:): 1
# 🥑(:avocado:): 1
# 🥶(:cold_face:): 1
# 🗳(:ballot_box_with_ballot:): 1
# 🚨(:police_car_light:): 1
# 🍍(:pineapple:): 1
# 🍄(:mushroom:): 1
# 😷(:face_with_medical_mask:): 1
# 👬(:two_men_holding_hands:): 1
# 🍰(:shortcake:): 1
# 👇(:backhand_index_pointing_down:): 1
# 👋(:waving_hand:): 1
# ➡(:right_arrow:): 1
# 🔗(:link:): 1
# 🐲(:dragon_face:): 1
# 💭(:thought_balloon:): 1
# ❎(:cross_mark_button:): 1
# 🔇(:muted_speaker:): 1
# 🔈(:speaker_low_volume:): 1
# 🔉(:speaker_medium_volume:): 1
# 😵(:dizzy_face:): 1
# 🍴(:fork_and_knife:): 1
# ⚠(:warning:): 1
# ⛈(:cloud_with_lightning_and_rain:): 1
# 💧(:droplet:): 1
# 🎵(:musical_note:): 1
# 🛸(:flying_saucer:): 1
# 🍿(:popcorn:): 1
# ©(:copyright:): 1
# 🌊(:water_wave:): 1
# 🎒(:school_backpack:): 1
# 🏖(:beach_with_umbrella:): 1
# 🐨(:koala:): 1
# 🐹(:hamster_face:): 1
# 🐱(:cat_face:): 1
# 🐴(:horse_face:): 1
# 🐰(:rabbit_face:): 1
# 🎢(:roller_coaster:): 1
# 😼(:cat_face_with_wry_smile:): 1
# 🤘🏻(:sign_of_the_horns_light_skin_tone:): 1
# 🤚🏽(:raised_back_of_hand_medium_skin_tone:): 1
# ✊(:raised_fist:): 1
# 🌚(:new_moon_face:): 1
# 👨‍❤️‍👨(:couple_with_heart_man_man:): 1
# 🕷(:spider:): 1
# 💍(:ring:): 1
# 📚(:books:): 1
# 👍🏽(:thumbs_up_medium_skin_tone:): 1
# 🖕🏽(:middle_finger_medium_skin_tone:): 1
# 👶🏽(:baby_medium_skin_tone:): 1
# 💑(:couple_with_heart:): 1
# 🍗(:poultry_leg:): 1
# 💅🏽(:nail_polish_medium_skin_tone:): 1
# 😽(:kissing_cat_face:): 1
# 📀(:dvd:): 1
# 😙(:kissing_face_with_smiling_eyes:): 1
# 🧗🏻‍♀️(:woman_climbing_light_skin_tone:): 1
# 🧢(:billed_cap:): 1
# 🧘(:person_in_lotus_position:): 1
# 🌪(:tornado:): 1
# 🍭(:lollipop:): 1
# 🦠(:microbe:): 1
# 🐉(:dragon:): 1
# 🐙(:octopus:): 1
# 📍(:round_pushpin:): 1
# 🤦🏿‍♂️(:man_facepalming_dark_skin_tone:): 1
